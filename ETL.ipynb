# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Bring in csv files and load into dataframes

# %%
#Bring in life expectancy csv
le_file = "CSVs/life_expectancy.csv"
life_exp = pd.read_csv(le_file)
life_exp.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# #Bring in food availability csv
# fa_file = "CSVs/FAO.csv"
# food = pd.read_csv(fa_file)
# food.head()

#Getting error here for some reason despite using multiple methods

# %%
#Bring in socioeconomic status csv
# ses_file = "CSVs/GLOB.SES.csv"
# ses = pd.read_csv(ses_file, encoding='utf-8')
# ses.head()

#Gets same error as above

# %% [markdown]
# ## Cleaning of Data

# %% [markdown]
# #### Life Expectancy

# %%
life_exp.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
#just show years of 2000 to 2010
life_exp = life_exp.loc[life_exp['Year']>=2000].loc[life_exp['Year']<=2010]
life_exp
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 5     Afghanistan  2010  Developing              58.8            279.0
# 6     Afghanistan  2009  Developing              58.6            281.0
# 7     Afghanistan  2008  Developing              58.1            287.0
# 8     Afghanistan  2007  Developing              57.5            295.0
# 9     Afghanistan  2006  Developing              57.3            295.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# Rename life expectancy column
life_exp = life_exp.rename(columns={"Life expectancy ":"life_expectancy", "Country":"country","Year":"year","Status":"status"})
life_exp.head()
# Out:
#        country  year      status  life_expectancy
# 5  Afghanistan  2010  Developing             58.8
# 6  Afghanistan  2009  Developing             58.6
# 7  Afghanistan  2008  Developing             58.1
# 8  Afghanistan  2007  Developing             57.5
# 9  Afghanistan  2006  Developing             57.3

# %%
#Get only the columns we want
life_exp = life_exp.drop(life_exp.iloc[:, 4:22], axis = 1) 
life_exp.head()
# Out:
#        country  year      status  life_expectancy
# 5  Afghanistan  2010  Developing             58.8
# 6  Afghanistan  2009  Developing             58.6
# 7  Afghanistan  2008  Developing             58.1
# 8  Afghanistan  2007  Developing             57.5
# 9  Afghanistan  2006  Developing             57.3

# %%
#confirmation
life_exp.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy'], dtype='object')

# %% [markdown]
# ## Create database connection

# %%
import getpass
password = getpass.getpass()
# Out:
# ········

# %%
#Create connection
engine = create_engine(f"postgresql://postgres:{password}@localhost:5432/ETL_db")

# %%
# See tables
engine.table_names()
# Out:
# ['life_expectancy']

# %% [markdown]
# ## Load dataframe into table in database

# %%
# Putting data from life_exp dataframe into table in SQL
life_exp.to_sql(name='life_expectancy', con=engine, if_exists='append', index=False)

# %%
#confirm sql query from table
pd.read_sql_query("select * from life_expectancy", con=engine).head()
# Out:
#        country  year      status  life_expectancy
# 0  Afghanistan  2010  Developing               59
# 1  Afghanistan  2009  Developing               59
# 2  Afghanistan  2008  Developing               58
# 3  Afghanistan  2007  Developing               58
# 4  Afghanistan  2006  Developing               57
